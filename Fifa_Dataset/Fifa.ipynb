# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa= pd.read_csv("data.csv")

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
 fifa.shape
# Out:
# (18207, 89)

# %%
fifa["Nationality"].value_counts()[0:10]
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
fifa["Nationality"].value_counts()[0:5]
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: Nationality, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(fifa["Nationality"].value_counts()[0:5].keys(),fifa["Nationality"].value_counts()[0:5],color="grey")
plt.show()

# %%
player_salary = fifa[["Name","Release Clause"]]

# %%
player_salary.head()
# Out:
#             Name Release Clause
# 1526   Léo Matos            €9M
# 3457  J. Windass            €9M
# 1419   Vieirinha            €9M
# 2519    P. Mpoku            €9M
# 4779   D. Geiger            €9M

# %%
Top_salary= fifa.sort_values(by=["Release Clause"],ascending= False)
Top_salary.head()
# Out:
#       Unnamed: 0      ID        Name  Age  \
# 1526        1526  158942   Léo Matos   32
# 3457        3457  219216  J. Windass   24
# 1419        1419  177553   Vieirinha   32
# 2519        2519  187858    P. Mpoku   26
# 4779        4779  235526   D. Geiger   20
#
#                                                Photo Nationality  \
# 1526  https://cdn.sofifa.org/players/4/19/158942.png      Brazil
# 3457  https://cdn.sofifa.org/players/4/19/219216.png     England
# 1419  https://cdn.sofifa.org/players/4/19/177553.png    Portugal
# 2519  https://cdn.sofifa.org/players/4/19/187858.png    DR Congo
# 4779  https://cdn.sofifa.org/players/4/19/235526.png     Germany
#
#                                       Flag  Overall  Potential  \
# 1526   https://cdn.sofifa.org/flags/54.png       76         76
# 3457   https://cdn.sofifa.org/flags/14.png       72         78
# 1419   https://cdn.sofifa.org/flags/38.png       76         76
# ...

# %%
Top_salary[["Name","Release Clause"]].head()
# Out:
#             Name Release Clause
# 1526   Léo Matos            €9M
# 3457  J. Windass            €9M
# 1419   Vieirinha            €9M
# 2519    P. Mpoku            €9M
# 4779   D. Geiger            €9M

# %%
fifa["Nationality"]=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Nationality, Length: 18207, dtype: bool

# %%
#Germany
Germany= fifa[fifa["Nationality"]=='Germany']

# %%
Germany.head(10)
# Out:
#     Unnamed: 0      ID           Name  Age  \
# 11          11  182521       T. Kroos   28
# 18          18  192448  M. ter Stegen   26
# 22          22  167495       M. Neuer   32
# 34          34  178603     M. Hummels   29
# 55          55  222492        L. Sané   22
# 66          66  189596      T. Müller   28
# 68          68  188350        M. Reus   29
# 74          74  176635        M. Özil   29
# 82          82  212622     J. Kimmich   23
# 95          95  183907     J. Boateng   29
#
#                                              Photo Nationality  \
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 22  https://cdn.sofifa.org/players/4/19/167495.png     Germany
# 34  https://cdn.sofifa.org/players/4/19/178603.png     Germany
# 55  https://cdn.sofifa.org/players/4/19/222492.png     Germany
# 66  https://cdn.sofifa.org/players/4/19/189596.png     Germany
# ...

# %%
Germany.sort_values(by=["Age"],ascending= False).head()
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 15133       15133  104900     M. Gurski   39
# 5319         5319   45473    C. Tiffert   36
# 12841       12841  101317  M. Ratajczak   36
# 8892         8892  169243    A. Mintzel   36
# 4045         4045  167452       O. Fink   36
#
#                                                 Photo Nationality  \
# 15133  https://cdn.sofifa.org/players/4/19/104900.png     Germany
# 5319    https://cdn.sofifa.org/players/4/19/45473.png     Germany
# 12841  https://cdn.sofifa.org/players/4/19/101317.png     Germany
# 8892   https://cdn.sofifa.org/players/4/19/169243.png     Germany
# 4045   https://cdn.sofifa.org/players/4/19/167452.png     Germany
#
#                                       Flag  Overall  Potential  \
# 15133  https://cdn.sofifa.org/flags/21.png       60         60
# 5319   https://cdn.sofifa.org/flags/21.png       70         70
# 12841  https://cdn.sofifa.org/flags/21.png       63         63
# ...

# %%
Germany.sort_values(by=["Potential"],ascending= False).head()
# Out:
#      Unnamed: 0      ID           Name  Age  \
# 55           55  222492        L. Sané   22
# 18           18  192448  M. ter Stegen   26
# 11           11  182521       T. Kroos   28
# 115         115  212190        N. Süle   22
# 22           22  167495       M. Neuer   32
#
#                                               Photo Nationality  \
# 55   https://cdn.sofifa.org/players/4/19/222492.png     Germany
# 18   https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 11   https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 115  https://cdn.sofifa.org/players/4/19/212190.png     Germany
# 22   https://cdn.sofifa.org/players/4/19/167495.png     Germany
#
#                                     Flag  Overall  Potential  \
# 55   https://cdn.sofifa.org/flags/21.png       86         92
# 18   https://cdn.sofifa.org/flags/21.png       89         92
# 11   https://cdn.sofifa.org/flags/21.png       90         90
# 115  https://cdn.sofifa.org/flags/21.png       84         90
# ...

# %%
Germany.sort_values(by=["Release Clause"],ascending= False).head()
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 4779         4779  235526       D. Geiger   20
# 2450         2450  170159     F. Bastians   30
# 11695       11695  232107  E. Oelschlägel   22
# 7755         7755  207897         A. Jung   26
# 10318       10318  238686         P. Sohm   26
#
#                                                 Photo Nationality  \
# 4779   https://cdn.sofifa.org/players/4/19/235526.png     Germany
# 2450   https://cdn.sofifa.org/players/4/19/170159.png     Germany
# 11695  https://cdn.sofifa.org/players/4/19/232107.png     Germany
# 7755   https://cdn.sofifa.org/players/4/19/207897.png     Germany
# 10318  https://cdn.sofifa.org/players/4/19/238686.png     Germany
#
#                                       Flag  Overall  Potential  \
# 4779   https://cdn.sofifa.org/flags/21.png       70         84
# 2450   https://cdn.sofifa.org/flags/21.png       74         74
# 11695  https://cdn.sofifa.org/flags/21.png       64         73
# ...

# %%
Germany[["Name","Release Clause"]].sort_values(by=["Release Clause"],ascending= False).head()
# Out:
#                  Name Release Clause
# 4779        D. Geiger            €9M
# 2450      F. Bastians            €9M
# 11695  E. Oelschlägel          €998K
# 7755          A. Jung          €997K
# 10318         P. Sohm          €991K

# %%
#StandingTackle
player_StandingTackle= fifa[["Name","StandingTackle"]]
player_StandingTackle
# Out:
#                      Name  StandingTackle
# 0                L. Messi            28.0
# 1       Cristiano Ronaldo            31.0
# 2               Neymar Jr            24.0
# 3                  De Gea            21.0
# 4            K. De Bruyne            58.0
# ...                   ...             ...
# 18202        J. Lundstram            48.0
# 18203  N. Christoffersson            15.0
# 18204           B. Worman            13.0
# 18205      D. Walker-Rice            25.0
# 18206           G. Nugent            43.0
#
# [18207 rows x 2 columns]

# %%
player_StandingTackle.sort_values(by=["StandingTackle"],ascending= False)
# Out:
#                   Name  StandingTackle
# 24        G. Chiellini            93.0
# 8         Sergio Ramos            92.0
# 71     T. Alderweireld            91.0
# 14            N. Kanté            91.0
# 27            Casemiro            90.0
# ...                ...             ...
# 13279     P. Mazzocchi             NaN
# 13280        Y. Ammour             NaN
# 13281   Jwa Joon Hyeop             NaN
# 13282       O. Marrufo             NaN
# 13283      Han Pengfei             NaN
#
# [18207 rows x 2 columns]

# %%
#SlidingTackle
player_SlidingTackle= fifa[["Name","SlidingTackle","Nationality","Club"]]
player_SlidingTackle
# Out:
#                 Name  SlidingTackle Nationality                 Club
# 0           L. Messi           26.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo           23.0    Portugal             Juventus
# 2          Neymar Jr           33.0      Brazil  Paris Saint-Germain
# 3             De Gea           13.0       Spain    Manchester United
# 4       K. De Bruyne           51.0     Belgium      Manchester City
# 5          E. Hazard           22.0     Belgium              Chelsea
# 6          L. Modrić           73.0     Croatia          Real Madrid
# 7          L. Suárez           38.0     Uruguay         FC Barcelona
# 8       Sergio Ramos           91.0       Spain          Real Madrid
# 9           J. Oblak           18.0    Slovenia      Atlético Madrid

# %%
top_SlidingTackle= player_SlidingTackle.sort_values(by=["SlidingTackle"],ascending= False)

# %%
top_SlidingTackle.head(10)
# Out:
#                 Name  SlidingTackle Nationality                 Club
# 8       Sergio Ramos           91.0       Spain          Real Madrid
# 6          L. Modrić           73.0     Croatia          Real Madrid
# 4       K. De Bruyne           51.0     Belgium      Manchester City
# 7          L. Suárez           38.0     Uruguay         FC Barcelona
# 2          Neymar Jr           33.0      Brazil  Paris Saint-Germain
# 0           L. Messi           26.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo           23.0    Portugal             Juventus
# 5          E. Hazard           22.0     Belgium              Chelsea
# 9           J. Oblak           18.0    Slovenia      Atlético Madrid
# 3             De Gea           13.0       Spain    Manchester United

# %%
#Club
fifa["Club"].value_counts()
# Out:
# Liverpool              33
# AS Monaco              33
# Burnley                33
# Eintracht Frankfurt    33
# CD Leganés             33
#                        ..
# Tromsø IL              20
# Paraná                 20
# Sligo Rovers           19
# Limerick FC            19
# Derry City             18
# Name: Club, Length: 651, dtype: int64

# %%
real_madrid= fifa[fifa["Club"]=='Real Madrid']

# %%
real_madrid[["Name","Club"]]
# Out:
#                   Name         Club
# 6            L. Modrić  Real Madrid
# 8         Sergio Ramos  Real Madrid
# 11            T. Kroos  Real Madrid
# 19         T. Courtois  Real Madrid
# 27            Casemiro  Real Madrid
# 30                Isco  Real Madrid
# 35             Marcelo  Real Madrid
# 36             G. Bale  Real Madrid
# 46            K. Navas  Real Madrid
# 62           R. Varane  Real Madrid
# 79       Marco Asensio  Real Madrid
# 105         K. Benzema  Real Madrid
# 123           Carvajal  Real Madrid
# 172      Lucas Vázquez  Real Madrid
# 188    Nacho Fernández  Real Madrid
# 328      Dani Ceballos  Real Madrid
# 417          Odriozola  Real Madrid
# 430            Mariano  Real Madrid
# 573    Marcos Llorente  Real Madrid
# 697       Kiko Casilla  Real Madrid
# 754            Vallejo  Real Madrid
# 1143   Vinícius Júnior  Real Madrid
# 2513       F. Valverde  Real Madrid
# 6724          Reguilón  Real Madrid
# 8732      Javi Sánchez  Real Madrid
# ...

# %%
real_madridName= real_madrid.sort_values(by=["Release Clause"],ascending= False)
real_madridName[["Name","Club","Release Clause"]].head(10)
# Out:
#                   Name         Club Release Clause
# 35             Marcelo  Real Madrid         €88.2M
# 13687        L. Zidane  Real Madrid          €788K
# 105         K. Benzema  Real Madrid         €75.9M
# 123           Carvajal  Real Madrid         €66.9M
# 46            K. Navas  Real Madrid         €62.5M
# 328      Dani Ceballos  Real Madrid         €56.3M
# 172      Lucas Vázquez  Real Madrid         €55.4M
# 188    Nacho Fernández  Real Madrid         €52.1M
# 1143   Vinícius Júnior  Real Madrid         €46.8M
# 430            Mariano  Real Madrid         €42.5M

# %%
real_madrid["Nationality"].value_counts()
# Out:
# Spain                 19
# Brazil                 3
# France                 3
# Wales                  1
# Argentina              1
# Dominican Republic     1
# Croatia                1
# Costa Rica             1
# Germany                1
# Belgium                1
# Uruguay                1
# Name: Nationality, dtype: int64

# %%
plt.figure(figsize=(7,5))
plt.bar(real_madrid["Nationality"].value_counts()[0:5].keys(),real_madrid["Nationality"].value_counts()[0:5])
plt.show()
